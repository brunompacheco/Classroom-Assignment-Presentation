# %%
import pickle

import numpy as np
import pandas as pd

from itertools import product, chain, combinations

from tqdm.notebook import tqdm

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
df_classes = pd.read_csv('PI_classes.csv', index_col=0)

df_classes
# Out:
#                                                   Bloco  Capacidade  \
# 0     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 1     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 2     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 3     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 4     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# ...                                                 ...         ...
# 1271   LIN Laboratório de Instrumentação Laboratório 16          16
# 1272   LIN Laboratório de Instrumentação Laboratório 16          16
# 1273         LPR Laboratório de Projetos Laboratório 16          16
# 1274         LPR Laboratório de Projetos Laboratório 16          16
# 1275         LPR Laboratório de Projetos Laboratório 16          16
#
#                 Andar    Sala  \
# 0     ARQ05 - 1ºAndar  ARQ201
# 1     ARQ05 - 1ºAndar  ARQ201
# 2     ARQ05 - 1ºAndar  ARQ201
# 3     ARQ05 - 1ºAndar  ARQ201
# 4     ARQ05 - 1ºAndar  ARQ201
# ...               ...     ...
# 1271              NaN     LIN
# 1272              NaN     LIN
# 1273              NaN     LPR
# 1274              NaN     LPR
# 1275              NaN     LPR
#
#                                               Materia   Codigo   Turma  \
# 0        Historia da Arte, Arquitetura e Urbanismo II  ARQ5622  02207A
# 1       História da Arte, Arquitetura e Urbanismo III  ARQ5623  04207A
# 2                        Arquitetura Latino Americana  ARQ5626  08207A
# 3                             Criatividade e Inovação  EGC5027   09207
# 4                                Análise Estrutural I  EMC5313   10203
# ...                                               ...      ...     ...
# 1271                               Projeto Integrador  DAS5104  07220A
# 1272                       Instrumentação em Controle  DAS5151  06220B
# 1273  Introdução à Engenharia de Controle e Automação  DAS5411  01220C
# 1274  Introdução à Engenharia de Controle e Automação  DAS5411  01220A
# 1275  Introdução à Engenharia de Controle e Automação  DAS5411  01220B
#
#         Horario  Oferecidas  Ocupadas
# 0     2. 0910-3          25        20
# 1     2. 1420-4          25        20
# 2     3. 0910-2          25        11
# 3     3. 1420-4          30        11
# 4     4. 0730-3          20        10
# ...         ...         ...       ...
# 1271  5. 1620-2          21         8
# 1272  6. 1010-2          15        10
# 1273  5. 1010-2          14        10
# 1274  5. 1330-2          14        12
# 1275  5. 1510-2          14        11
#
# [1276 rows x 10 columns]

# %%
df_rooms = pd.read_csv('PI_rooms.csv')
df_rooms
# Out:
#                 Lugar    Sala  Carteiras  \
# 0     ARQ05 - 1ºAndar  ARQ201         45
# 1     ARQ04 - 1ºAndar  ARQ202         40
# 2     ARQ03 - 1ºAndar  ARQ203         40
# 3      ARQ02 - Térreo  ARQ204         40
# 4    ARQ09 - 2º Andar  ARQ301         20
# ..                ...     ...        ...
# 123               NaN  PGEAS2         25
# 124               NaN  SPL313         30
# 125               NaN  SPL314         15
# 126               NaN  SPL315         30
# 127               NaN  SPL316         15
#
#                                        Características  Ar condicionado  \
# 0    2 Ar condicionado, 1 Mesa do professor (sala d...                2
# 1    1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# 2    2 Ar condicionado, 1 Projetor multimídia, 1 Me...                2
# 3    2 Ar condicionado, 1 Projetor multimídia, 1 Qu...                2
# 4    1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# ..                                                 ...              ...
# 123                                        Laboratório                0
# 124                                        Laboratório                0
# 125                                        Laboratório                0
# 126                                        Laboratório                0
# 127                                        Laboratório                0
#
#      Projetor  Laboratório
# 0           1            0
# 1           1            0
# 2           1            0
# 3           1            0
# 4           1            0
# ..        ...          ...
# 123         0            1
# 124         0            1
# 125         0            1
# 126         0            1
# 127         0            1
#
# [128 rows x 7 columns]

# %% [markdown]
# # Lecture required seats fix

# %%
# we assume that the actual amount of seats required is at most the amount offered by the class allocated
df_classes['Ocupadas_fix'] = df_classes[['Capacidade', 'Ocupadas']].min(axis='columns')

# %% [markdown]
# # Lab rooms+lectures

# %%
labs = df_rooms[df_rooms['Laboratório'] > 0]['Sala']

# remove labs
df_rooms = df_rooms[df_rooms['Laboratório'] == 0].drop(columns=['Laboratório'])

print(f"Labs: {len(labs)}")

df_rooms
# Out:
# Labs: 60
#                Lugar    Sala  Carteiras  \
# 0    ARQ05 - 1ºAndar  ARQ201         45
# 1    ARQ04 - 1ºAndar  ARQ202         40
# 2    ARQ03 - 1ºAndar  ARQ203         40
# 3     ARQ02 - Térreo  ARQ204         40
# 4   ARQ09 - 2º Andar  ARQ301         20
# ..               ...     ...        ...
# 65               NaN  EQA018         45
# 66               NaN  EQA020         35
# 67               NaN  EQA021         35
# 68               NaN  EQA022         35
# 69               NaN  EQA023         45
#
#                                       Características  Ar condicionado  \
# 0   2 Ar condicionado, 1 Mesa do professor (sala d...                2
# 1   1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# 2   2 Ar condicionado, 1 Projetor multimídia, 1 Me...                2
# 3   2 Ar condicionado, 1 Projetor multimídia, 1 Qu...                2
# 4   1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# ..                                                ...              ...
# 65  50 Carteira com cadeira separada, 1 Projetor m...                2
# 66  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 67  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 68  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 69  2 Ar condicionado, 1 Mesa do professor (sala d...                2
#
#     Projetor
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 65         1
# 66         1
# 67         1
# 68         1
# 69         1
#
# [68 rows x 6 columns]

# %%
# remove lectures that occur in labs
df_classes = df_classes[~df_classes['Sala'].isin(labs)]
df_classes = df_classes[df_classes['Sala'] != 'LABCIG']
df_classes
# Out:
#                                                   Bloco  Capacidade  \
# 0     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 1     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 2     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 3     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 4     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# ...                                                 ...         ...
# 1095           EQA023 Sala de aula Sala com carteira 45          45
# 1096           EQA023 Sala de aula Sala com carteira 45          45
# 1097           EQA023 Sala de aula Sala com carteira 45          45
# 1098           EQA023 Sala de aula Sala com carteira 45          45
# 1099           EQA023 Sala de aula Sala com carteira 45          45
#
#                 Andar    Sala  \
# 0     ARQ05 - 1ºAndar  ARQ201
# 1     ARQ05 - 1ºAndar  ARQ201
# 2     ARQ05 - 1ºAndar  ARQ201
# 3     ARQ05 - 1ºAndar  ARQ201
# 4     ARQ05 - 1ºAndar  ARQ201
# ...               ...     ...
# 1095              NaN  EQA023
# 1096              NaN  EQA023
# 1097              NaN  EQA023
# 1098              NaN  EQA023
# 1099              NaN  EQA023
#
#                                                 Materia   Codigo   Turma  \
# 0          Historia da Arte, Arquitetura e Urbanismo II  ARQ5622  02207A
# 1         História da Arte, Arquitetura e Urbanismo III  ARQ5623  04207A
# 2                          Arquitetura Latino Americana  ARQ5626  08207A
# 3                               Criatividade e Inovação  EGC5027   09207
# 4                                  Análise Estrutural I  EMC5313   10203
# ...                                                 ...      ...     ...
# 1095  Operações Unitárias de Transferência de Calor ...  EQA5333   08216
# 1096                      Fenômenos de Transferência II  EQA5416   06216
# 1097                 Programação Econômica e Financeira  EPS5211   07216
# 1098  Operações Unitárias de Transferência de Quanti...  EQA5313   06215
# 1099  Operações Unitárias de Transferência de Quanti...  EQA5313   06216
#
#         Horario  Oferecidas  Ocupadas  Ocupadas_fix
# 0     2. 0910-3          25        20            20
# 1     2. 1420-4          25        20            20
# 2     3. 0910-2          25        11            11
# 3     3. 1420-4          30        11            11
# 4     4. 0730-3          20        10            10
# ...         ...         ...       ...           ...
# 1095  5. 1330-2          20        20            20
# 1096  5. 1510-2          20        20            20
# 1097  6. 0730-3          31        26            26
# 1098  6. 1330-2          20        15            15
# 1099  6. 1330-2          20        13            13
#
# [1100 rows x 11 columns]

# %% [markdown]
# # Room names

# %%
df_classes['Sala'].str.replace(' ','').nunique()
# Out:
# 65

# %%
df_rooms['Sala'].str.replace(' ','').nunique()
# Out:
# 68

# %%
df_classes['Sala'] = df_classes['Sala'].str.replace(' ', '')
df_rooms['Sala'] = df_rooms['Sala'].str.replace(' ', '')

# %%
# rooms in `df_classes` that are not in `df_rooms`
set(df_classes['Sala'].unique()).difference(set(df_rooms['Sala'].unique()))
# Out:
# set()

# %% [markdown]
# # ARQ rooms

# %%
arq_rooms = df_classes[df_classes['Codigo'].str.contains('ARQ') & \
                       df_classes['Sala'].str.contains('ARQ')]['Sala'].unique()

df_rooms = df_rooms[~df_rooms['Sala'].isin(arq_rooms)]

df_rooms
# Out:
#                 Lugar    Sala  Carteiras  \
# 9      ARQ01- 2ºAndar  ARQ308         20
# 14    CTC101 - Térreo  CTC101         40
# 15    CTC102 - Térreo  CTC102         80
# 16    CTC103 - Térreo  CTC103         40
# 17    CTC104 - Térreo  CTC104         35
# 18    CTC105 - Térreo  CTC105         40
# 19    CTC106 - Térreo  CTC106         40
# 20    CTC107 - Térreo  CTC107         40
# 21    CTC108 - Térreo  CTC108         40
# 22    CTC109 - Térreo  CTC109         35
# 23    CTC110 - Térreo  CTC110         40
# 24    CTC111 - Térreo  CTC111         40
# 25    CTC112 - Térreo  CTC112         35
# 26    CTC113 - Térreo  CTC113         40
# 27   CTC201 - 1ºAndar  CTC201         60
# 28   CTC202 - 1ºAndar  CTC202         60
# 29   CTC203 - 1ºAndar  CTC203         60
# 30   CTC204 - 1ºAndar  CTC204         60
# 31   CTC205 - 1ºAndar  CTC205         40
# 32   CTC206 - 1ºAndar  CTC206         40
# 33   CTC207 - 1ºAndar  CTC207         60
# 34   CTC208 - 1ºAndar  CTC208         60
# 35   CTC209 - 1ºAndar  CTC209         60
# 36   CTC210 - 1ºAndar  CTC210         60
# 37   CTC301 - 2ºAndar  CTC301         40
# 38   CTC302 - 2ºAndar  CTC302         40
# 39   CTC303 - 2ºAndar  CTC303         40
# 40   CTC304 - 2ºAndar  CTC304         60
# 41   CTC305 - 2ºAndar  CTC305         60
# 42   CTC306 - 2ºAndar  CTC306         30
# 43                NaN  ECV303         55
# 44                NaN  ECV310         52
# 45                NaN  ECV311         29
# 46                NaN  ECV312         29
# 47                NaN  ECV313         53
# 48       EEL - Térreo  EEL003         40
# 49       EEL - Térreo  EEL004        100
# 50       EEL - Térreo  EEL008         40
# 51       EEL - Térreo  EEL009         40
# 52       EEL - Térreo  EEL010         40
# 54  ENS211 - 2º andar  ENS211         40
# 55  ENS212 - 2º andar  ENS212         15
# 56  ENS213 - 2º andar  ENS213         50
# 57  ENS215 - 2º andar  ENS215         40
# 58  ENS216 - 2º andar  ENS216         40
# 59  ENS217 - 2º andar  ENS217         26
# 60                NaN  EPS001         50
# 61                NaN  EPS002         30
# 62                NaN  EPS003         50
# 63                NaN  EQA015         25
# 64                NaN  EQA016         25
# 65                NaN  EQA018         45
# 66                NaN  EQA020         35
# 67                NaN  EQA021         35
# 68                NaN  EQA022         35
# 69                NaN  EQA023         45
#
#                                       Características  Ar condicionado  \
# 9   1 Mesa do professor (sala de aula), 1 Quadro p...                1
# 14  1 Projetor multimídia, 40 Carteira com cadeira...                2
# 15  80 Carteira com cadeira separada, 2 Ar condici...                2
# 16  40 Carteira com cadeira separada, 2 Ar condici...                2
# 17  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 18  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 19  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 20  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 21  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 22  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 23  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 24  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 25  1 Ar condicionado, 35 Carteira com cadeira sep...                1
# 26  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 27  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 28  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 29  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 30  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 31  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 32  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 33  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 34  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 35  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 36  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 37  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 38  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 39  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 40  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 41  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 42  1 Ar condicionado, 30 Carteira com cadeira sep...                1
# 43  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 44  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 45  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 46  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 47  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 48  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 49  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 50  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 51  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 52  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 54  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 55  1 Ar condicionado, 15 Carteira com cadeira sep...                1
# 56  2 Ar condicionado, 50 Carteira com cadeira sep...                2
# 57  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 58  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 59  1 Ar condicionado, 26 Carteira com cadeira sep...                1
# 60  50 Carteira com cadeira separada, 2 Ar condici...                2
# 61  30 Carteira com cadeira separada, 1 Ar condici...                1
# 62  50 Carteira com cadeira separada, 1 Ar condici...                1
# 63  25 Carteira com cadeira separada, 1 Projetor m...                1
# 64  1 Ar condicionado, 1 Mesa do professor (sala d...                1
# 65  50 Carteira com cadeira separada, 1 Projetor m...                2
# 66  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 67  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 68  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 69  2 Ar condicionado, 1 Mesa do professor (sala d...                2
#
#     Projetor
# 9          1
# 14         1
# 15         1
# 16         1
# 17         1
# 18         1
# 19         1
# 20         1
# 21         1
# 22         1
# 23         1
# 24         1
# 25         1
# 26         1
# 27         1
# 28         1
# 29         1
# 30         1
# 31         1
# 32         1
# 33         1
# 34         1
# 35         1
# 36         1
# 37         1
# 38         1
# 39         1
# 40         1
# 41         1
# 42         1
# 43         1
# 44         1
# 45         1
# 46         1
# 47         1
# 48         1
# 49         1
# 50         1
# 51         1
# 52         1
# 54         1
# 55         1
# 56         1
# 57         1
# 58         1
# 59         1
# 60         1
# 61         1
# 62         1
# 63         1
# 64         1
# 65         1
# 66         1
# 67         1
# 68         1
# 69         1

# %%
df_classes = df_classes[~df_classes['Codigo'].str.contains('ARQ')]

df_classes
# Out:
#                                                   Bloco  Capacidade  \
# 3     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 4     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 7     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 9     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          40
# 11    CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          40
# ...                                                 ...         ...
# 1095           EQA023 Sala de aula Sala com carteira 45          45
# 1096           EQA023 Sala de aula Sala com carteira 45          45
# 1097           EQA023 Sala de aula Sala com carteira 45          45
# 1098           EQA023 Sala de aula Sala com carteira 45          45
# 1099           EQA023 Sala de aula Sala com carteira 45          45
#
#                 Andar    Sala  \
# 3     ARQ05 - 1ºAndar  ARQ201
# 4     ARQ05 - 1ºAndar  ARQ201
# 7     ARQ05 - 1ºAndar  ARQ201
# 9     ARQ04 - 1ºAndar  ARQ202
# 11    ARQ04 - 1ºAndar  ARQ202
# ...               ...     ...
# 1095              NaN  EQA023
# 1096              NaN  EQA023
# 1097              NaN  EQA023
# 1098              NaN  EQA023
# 1099              NaN  EQA023
#
#                                                 Materia   Codigo   Turma  \
# 3                               Criatividade e Inovação  EGC5027   09207
# 4                                  Análise Estrutural I  EMC5313   10203
# 7                          Química Geral e Inorgânica I  QMC5152   01216
# 9                               Instalações Prediais II  ECV5644  05207B
# 11                               Estruturas de Concreto  ECV5228   08211
# ...                                                 ...      ...     ...
# 1095  Operações Unitárias de Transferência de Calor ...  EQA5333   08216
# 1096                      Fenômenos de Transferência II  EQA5416   06216
# 1097                 Programação Econômica e Financeira  EPS5211   07216
# 1098  Operações Unitárias de Transferência de Quanti...  EQA5313   06215
# 1099  Operações Unitárias de Transferência de Quanti...  EQA5313   06216
#
#         Horario  Oferecidas  Ocupadas  Ocupadas_fix
# 3     3. 1420-4          30        11            11
# 4     4. 0730-3          20        10            10
# 7     6. 0820-2          40        26            26
# 9     2. 1330-3          33        31            31
# 11    3. 0730-3          30        22            22
# ...         ...         ...       ...           ...
# 1095  5. 1330-2          20        20            20
# 1096  5. 1510-2          20        20            20
# 1097  6. 0730-3          31        26            26
# 1098  6. 1330-2          20        15            15
# 1099  6. 1330-2          20        13            13
#
# [1048 rows x 11 columns]

# %% [markdown]
# # Course-class naming

# %%
df_classes['Turma'].nunique()
# Out:
# 286

# %%
joint_classes = df_classes.groupby(['Codigo', 'Sala', 'Horario'])['Turma'].nunique()
classes_to_join = df_classes.groupby(['Codigo', 'Sala', 'Horario'])['Turma'].unique()[joint_classes[joint_classes > 1].index]
classes_new_name = df_classes.groupby(['Codigo', 'Sala', 'Horario'])['Turma'].first()[joint_classes[joint_classes > 1].index]
classes_new_name
# Out:
# Codigo   Sala    Horario
# DAS5102  CTC208  5. 1010-2    02220A
# DAS5109  EEL008  5. 1620-2    05220A
# DAS5120  CTC111  5. 1510-2    06220A
#          EEL010  3. 1010-2    06220A
# DAS5142  CTC113  6. 1330-2    07220A
#                                ...
# MTM3104  CTC102  4. 1620-2     04203
#                  6. 1620-2     04203
# QMC5222  CTC204  6. 1330-2     02215
# QMC5229  CTC304  4. 1010-2     03215
#          CTC305  6. 0730-2     03215
# Name: Turma, Length: 159, dtype: object

# %%
classes_to_join
# Out:
# Codigo   Sala    Horario
# DAS5102  CTC208  5. 1010-2            [02220A, 02220B]
# DAS5109  EEL008  5. 1620-2            [05220A, 05220B]
# DAS5120  CTC111  5. 1510-2    [06220A, 06220B, 06220C]
#          EEL010  3. 1010-2    [06220A, 06220B, 06220C]
# DAS5142  CTC113  6. 1330-2    [07220A, 07220B, 07220C]
#                                         ...
# MTM3104  CTC102  4. 1620-2              [04203, 04212]
#                  6. 1620-2              [04203, 04212]
# QMC5222  CTC204  6. 1330-2              [02215, 02216]
# QMC5229  CTC304  4. 1010-2              [03215, 03216]
#          CTC305  6. 0730-2              [03215, 03216]
# Name: Turma, Length: 159, dtype: object

# %%
classes_renaming = {c_i: c_o for c_is, c_o in zip(classes_to_join.values, classes_new_name.values) for c_i in c_is}
classes_renaming
# Out:
# {'02220A': '02220A',
#  '02220B': '02220A',
#  '05220A': '05220A',
#  '05220B': '05220A',
#  '06220A': '06220A',
#  '06220B': '06220A',
#  '06220C': '06220A',
#  '07220A': '07220A',
#  '07220B': '07220A',
#  '07220C': '07220A',
#  '03220A': '03220A',
#  '03220B': '03220A',
#  '03220C': '03220A',
#  '03220D': '03220A',
#  '04220A': '04220A',
#  '04220B': '04220A',
#  '01220A': '01220A',
#  '01220B': '01220A',
#  '01220C': '01220A',
#  '06201A': '06201A',
#  '06201C': '06201A',
#  '06212': '06212',
#  '06201B': '06201B',
#  '06211B': '06201B',
#  '05201B': '05201B',
#  '05201A': '05201A',
#  '05212': '05201A',
#  '07211': '06212',
#  '09201A': '09201A',
#  '09201B': '09201B',
#  '07212': '05201B',
#  '08201B': '07212',
#  '01208B': '01208B',
#  '01208D': '01208B',
#  '01208A': '01208A',
#  '03202A': '03202A',
#  '03235': '03202A',
#  '08213A': '02220A',
#  '06203': '06203',
#  '07214': '06203B',
#  '06220': '06220',
#  '06220F': '06220',
#  '01202B': '01202B',
#  '01235B': '01202B',
#  '01202A': '01202A',
#  '01235A': '01202A',
#  '04235A': '04202B',
#  '04235B': '04202B',
#  '04202A': '04202A',
#  '04202B': '04202B',
#  '04202C': '04202B',
#  '10213': '04202A',
#  '04213A': '04202B',
#  '04202D': '04202A',
#  '04213B': '04202A',
#  '05202C': '05202A',
#  '05213': '05202C',
#  '05235B': '05202B',
#  '05202A': '05202A',
#  '05202B': '05202B',
#  '05235A': '05202A',
#  '05202D': '05202A',
#  '05213A': '05202A',
#  '05213B': '05202A',
#  '05235': '05202A',
#  '06202C': '06202A',
#  '06202D': '06202A',
#  '06202A': '06202A',
#  '06202B': '06202A',
#  '06235A': '06202A',
#  '06235B': '06202C',
#  '06202E': '06202A',
#  '06202F': '06202A',
#  '06213': '06202A',
#  '06213B': '06202A',
#  '07202B': '07202B',
#  '07213': '04212',
#  '07202A': '07202A',
#  '07202C': '07202A',
#  '07202D': '07202A',
#  '07213B': '07202A',
#  '09235': '09202',
#  '10202': '09235',
#  '07235': '07235',
#  '07235B': '07235',
#  '09202': '09202',
#  '08215': '08215',
#  '08216': '08215',
#  '10212': '09211',
#  '06203A': '06203A',
#  '06203B': '06203B',
#  '09203': '09203',
#  '09203B': '09203',
#  '09203C': '09203',
#  '05203A': '05203A',
#  '05203C': '05203A',
#  '05203E': '05203A',
#  '06214': '05203A',
#  '03203B': '03203B',
#  '04214': '03213B',
#  '03215': '03215',
#  '03216': '03215',
#  '04203': '04203',
#  '05214A': '04203A',
#  '04203B': '04203B',
#  '05214B': '04203B',
#  '07203A': '07203A',
#  '08214': '07203A',
#  '06214A': '05203A',
#  '05203B': '05203B',
#  '06214B': '05203B',
#  '07203B': '07203B',
#  '08214B': '07203B',
#  '06203C': '06203',
#  '06203D': '06203',
#  '05214': '05214',
#  '10203': '07220',
#  '07220': '07220',
#  '04214B': '03203B',
#  '03203A': '03203A',
#  '04214A': '03203A',
#  '04203A': '04203A',
#  '04212': '04203',
#  '07212A': '05201A',
#  '08212': '06201B',
#  '09211': '09211',
#  '01203A': '01203A',
#  '01214': '01203A',
#  '01212': '01212',
#  '02201B': '01212',
#  '06215': '06215',
#  '06216': '06215',
#  '09215': '09215',
#  '09216': '09215',
#  '02212A': '02212A',
#  '02213': '02213',
#  '03212': '03212',
#  '03214B': '03212',
#  '03214A': '02213',
#  '03213B': '03213B',
#  '04201A': '04201A',
#  '04201B': '04201A',
#  '02208A': '02208A',
#  '02208B': '02208A',
#  '09235A': '07202A',
#  '09235B': '07202B',
#  '03208A': '03208A',
#  '03208B': '03208A',
#  '03208C': '03208A',
#  '06235': '03208A',
#  '04208A': '04208A',
#  '04208B': '04208A',
#  '01238A': '01238A',
#  '01238B': '01238A',
#  '01238C': '01238A',
#  '02238A': '02238A',
#  '02238B': '02238A',
#  '02215A': '02215A',
#  '02215B': '02215A',
#  '02215': '02215',
#  '02216': '02215'}

# %%
df_classes['Turma'] = df_classes['Turma'].map(classes_renaming)
df_classes['Turma'].nunique()
# Out:
# <ipython-input-24-87087d70a669>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_classes['Turma'] = df_classes['Turma'].map(classes_renaming)
# 68

# %%
# drop letters from class
df_classes['Codigo'] = df_classes['Codigo'] + '-' + df_classes['Turma']
# Out:
# <ipython-input-25-978ab8735e6f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_classes['Codigo'] = df_classes['Codigo'] + '-' + df_classes['Turma']

# %% [markdown]
# # Course-room matching

# %%
# are there multiple classes attending the same lecture at the same time in the same room?
seats_req = df_classes.groupby(['Codigo', 'Horario', 'Sala'])['Ocupadas'].sum()
seats_req
# Out:
# Codigo          Horario    Sala
# BQA5126-06215   2. 1330-2  EQA020    13
#                 4. 1330-2  EQA020    13
# DAS5102-02220A  5. 1010-2  CTC208    36
# DAS5104-07220A  2. 1010-2  CTC108     8
# DAS5109-05220A  5. 1620-2  EEL008    33
#                                      ..
# MTM3104-04203   6. 1620-2  CTC102    57
# QMC5222-02215   6. 1330-2  CTC204    63
# QMC5229-03215   4. 1010-2  CTC304    37
#                 6. 0730-2  CTC305    37
# QMC5350-02215   6. 1010-2  EQA020    16
# Name: Ocupadas, Length: 459, dtype: int64

# %%
seats_avail = df_classes.groupby(['Codigo', 'Horario', 'Sala'])['Capacidade'].first()
seats_avail
# Out:
# Codigo          Horario    Sala
# BQA5126-06215   2. 1330-2  EQA020    35
#                 4. 1330-2  EQA020    35
# DAS5102-02220A  5. 1010-2  CTC208    60
# DAS5104-07220A  2. 1010-2  CTC108    40
# DAS5109-05220A  5. 1620-2  EEL008    40
#                                      ..
# MTM3104-04203   6. 1620-2  CTC102    80
# QMC5222-02215   6. 1330-2  CTC204    60
# QMC5229-03215   4. 1010-2  CTC304    60
#                 6. 0730-2  CTC305    60
# QMC5350-02215   6. 1010-2  EQA020    35
# Name: Capacidade, Length: 459, dtype: int64

# %%
# every course-room-time combination is considered a lecture (actualy a long lecture)
df_lectures = df_classes.groupby(['Codigo', 'Horario', 'Sala'])['Ocupadas'].sum().reset_index()
df_lectures['long_lecture'] = df_lectures.index

# each row is a lecture
df_lectures
# Out:
#              Codigo    Horario    Sala  Ocupadas  long_lecture
# 0     BQA5126-06215  2. 1330-2  EQA020        13             0
# 1     BQA5126-06215  4. 1330-2  EQA020        13             1
# 2    DAS5102-02220A  5. 1010-2  CTC208        36             2
# 3    DAS5104-07220A  2. 1010-2  CTC108         8             3
# 4    DAS5109-05220A  5. 1620-2  EEL008        33             4
# ..              ...        ...     ...       ...           ...
# 454   MTM3104-04203  6. 1620-2  CTC102        57           454
# 455   QMC5222-02215  6. 1330-2  CTC204        63           455
# 456   QMC5229-03215  4. 1010-2  CTC304        37           456
# 457   QMC5229-03215  6. 0730-2  CTC305        37           457
# 458   QMC5350-02215  6. 1010-2  EQA020        16           458
#
# [459 rows x 5 columns]

# %%
df_lectures['n_lectures'] = df_lectures['Horario'].str.split('-').apply(lambda x: x[-1])
df_lectures
# Out:
#              Codigo    Horario    Sala  Ocupadas  long_lecture n_lectures
# 0     BQA5126-06215  2. 1330-2  EQA020        13             0          2
# 1     BQA5126-06215  4. 1330-2  EQA020        13             1          2
# 2    DAS5102-02220A  5. 1010-2  CTC208        36             2          2
# 3    DAS5104-07220A  2. 1010-2  CTC108         8             3          2
# 4    DAS5109-05220A  5. 1620-2  EEL008        33             4          2
# ..              ...        ...     ...       ...           ...        ...
# 454   MTM3104-04203  6. 1620-2  CTC102        57           454          2
# 455   QMC5222-02215  6. 1330-2  CTC204        63           455          2
# 456   QMC5229-03215  4. 1010-2  CTC304        37           456          2
# 457   QMC5229-03215  6. 0730-2  CTC305        37           457          2
# 458   QMC5350-02215  6. 1010-2  EQA020        16           458          2
#
# [459 rows x 6 columns]

# %%
df_lectures = df_lectures.loc[df_lectures.index.repeat(df_lectures['n_lectures'])]
df_lectures = df_lectures.reset_index().drop(columns=['index', 'n_lectures'])
df_lectures['lecture'] = df_lectures.index

df_lectures
# Out:
#               Codigo    Horario    Sala  Ocupadas  long_lecture  lecture
# 0      BQA5126-06215  2. 1330-2  EQA020        13             0        0
# 1      BQA5126-06215  2. 1330-2  EQA020        13             0        1
# 2      BQA5126-06215  4. 1330-2  EQA020        13             1        2
# 3      BQA5126-06215  4. 1330-2  EQA020        13             1        3
# 4     DAS5102-02220A  5. 1010-2  CTC208        36             2        4
# ...              ...        ...     ...       ...           ...      ...
# 1007   QMC5229-03215  4. 1010-2  CTC304        37           456     1007
# 1008   QMC5229-03215  6. 0730-2  CTC305        37           457     1008
# 1009   QMC5229-03215  6. 0730-2  CTC305        37           457     1009
# 1010   QMC5350-02215  6. 1010-2  EQA020        16           458     1010
# 1011   QMC5350-02215  6. 1010-2  EQA020        16           458     1011
#
# [1012 rows x 6 columns]

# %% [markdown]
# # Time periods

# %%
days = np.arange(1,7+1)
times = ['0730', '0820', '0910', '1010', '1100', '1330', '1420', '1510', '1620', '1710', '1830', '1920', '2020', '2110']

time_periods = product(days, times)
time_periods = [str(d)+'-'+t for d, t in time_periods]
time_periods
# Out:
# ['1-0730',
#  '1-0820',
#  '1-0910',
#  '1-1010',
#  '1-1100',
#  '1-1330',
#  '1-1420',
#  '1-1510',
#  '1-1620',
#  '1-1710',
#  '1-1830',
#  '1-1920',
#  '1-2020',
#  '1-2110',
#  '2-0730',
#  '2-0820',
#  '2-0910',
#  '2-1010',
#  '2-1100',
#  '2-1330',
#  '2-1420',
#  '2-1510',
#  '2-1620',
#  '2-1710',
#  '2-1830',
#  '2-1920',
#  '2-2020',
#  '2-2110',
#  '3-0730',
#  '3-0820',
#  '3-0910',
#  '3-1010',
#  '3-1100',
#  '3-1330',
#  '3-1420',
#  '3-1510',
#  '3-1620',
#  '3-1710',
#  '3-1830',
#  '3-1920',
#  '3-2020',
#  '3-2110',
#  '4-0730',
#  '4-0820',
#  '4-0910',
#  '4-1010',
#  '4-1100',
#  '4-1330',
#  '4-1420',
#  '4-1510',
#  '4-1620',
#  '4-1710',
#  '4-1830',
#  '4-1920',
#  '4-2020',
#  '4-2110',
#  '5-0730',
#  '5-0820',
#  '5-0910',
#  '5-1010',
#  '5-1100',
#  '5-1330',
#  '5-1420',
#  '5-1510',
#  '5-1620',
#  '5-1710',
#  '5-1830',
#  '5-1920',
#  '5-2020',
#  '5-2110',
#  '6-0730',
#  '6-0820',
#  '6-0910',
#  '6-1010',
#  '6-1100',
#  '6-1330',
#  '6-1420',
#  '6-1510',
#  '6-1620',
#  '6-1710',
#  '6-1830',
#  '6-1920',
#  '6-2020',
#  '6-2110',
#  '7-0730',
#  '7-0820',
#  '7-0910',
#  '7-1010',
#  '7-1100',
#  '7-1330',
#  '7-1420',
#  '7-1510',
#  '7-1620',
#  '7-1710',
#  '7-1830',
#  '7-1920',
#  '7-2020',
#  '7-2110']

# %%
df_lectures['Horario'] = df_lectures['Horario'].str.split('-').apply(lambda x: x[0])
df_lectures['Horario'] = df_lectures['Horario'].str.replace('. ', '-')

df_lectures
# Out:
# <ipython-input-32-01be645fcdbb>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lectures['Horario'] = df_lectures['Horario'].str.replace('. ', '-')
#               Codigo Horario    Sala  Ocupadas  long_lecture  lecture
# 0      BQA5126-06215  2-1330  EQA020        13             0        0
# 1      BQA5126-06215  2-1330  EQA020        13             0        1
# 2      BQA5126-06215  4-1330  EQA020        13             1        2
# 3      BQA5126-06215  4-1330  EQA020        13             1        3
# 4     DAS5102-02220A  5-1010  CTC208        36             2        4
# ...              ...     ...     ...       ...           ...      ...
# 1007   QMC5229-03215  4-1010  CTC304        37           456     1007
# 1008   QMC5229-03215  6-0730  CTC305        37           457     1008
# 1009   QMC5229-03215  6-0730  CTC305        37           457     1009
# 1010   QMC5350-02215  6-1010  EQA020        16           458     1010
# 1011   QMC5350-02215  6-1010  EQA020        16           458     1011
#
# [1012 rows x 6 columns]

# %% [markdown]
# # Formulation

# %%
df_lectures = df_lectures.rename({
    'Codigo': 'course',
    'Horario': 'time_period',
    'Sala': 'room',
    'Ocupadas': 'size',
}, axis='columns')

df_lectures
# Out:
#               course time_period    room  size  long_lecture  lecture
# 0      BQA5126-06215      2-1330  EQA020    13             0        0
# 1      BQA5126-06215      2-1330  EQA020    13             0        1
# 2      BQA5126-06215      4-1330  EQA020    13             1        2
# 3      BQA5126-06215      4-1330  EQA020    13             1        3
# 4     DAS5102-02220A      5-1010  CTC208    36             2        4
# ...              ...         ...     ...   ...           ...      ...
# 1007   QMC5229-03215      4-1010  CTC304    37           456     1007
# 1008   QMC5229-03215      6-0730  CTC305    37           457     1008
# 1009   QMC5229-03215      6-0730  CTC305    37           457     1009
# 1010   QMC5350-02215      6-1010  EQA020    16           458     1010
# 1011   QMC5350-02215      6-1010  EQA020    16           458     1011
#
# [1012 rows x 6 columns]

# %%
df_rooms = df_rooms.rename({
    'Sala': 'room',
    'Carteiras': 'size'
}, axis='columns')

df_rooms
# Out:
#                 Lugar    room  size  \
# 9      ARQ01- 2ºAndar  ARQ308    20
# 14    CTC101 - Térreo  CTC101    40
# 15    CTC102 - Térreo  CTC102    80
# 16    CTC103 - Térreo  CTC103    40
# 17    CTC104 - Térreo  CTC104    35
# 18    CTC105 - Térreo  CTC105    40
# 19    CTC106 - Térreo  CTC106    40
# 20    CTC107 - Térreo  CTC107    40
# 21    CTC108 - Térreo  CTC108    40
# 22    CTC109 - Térreo  CTC109    35
# 23    CTC110 - Térreo  CTC110    40
# 24    CTC111 - Térreo  CTC111    40
# 25    CTC112 - Térreo  CTC112    35
# 26    CTC113 - Térreo  CTC113    40
# 27   CTC201 - 1ºAndar  CTC201    60
# 28   CTC202 - 1ºAndar  CTC202    60
# 29   CTC203 - 1ºAndar  CTC203    60
# 30   CTC204 - 1ºAndar  CTC204    60
# 31   CTC205 - 1ºAndar  CTC205    40
# 32   CTC206 - 1ºAndar  CTC206    40
# 33   CTC207 - 1ºAndar  CTC207    60
# 34   CTC208 - 1ºAndar  CTC208    60
# 35   CTC209 - 1ºAndar  CTC209    60
# 36   CTC210 - 1ºAndar  CTC210    60
# 37   CTC301 - 2ºAndar  CTC301    40
# 38   CTC302 - 2ºAndar  CTC302    40
# 39   CTC303 - 2ºAndar  CTC303    40
# 40   CTC304 - 2ºAndar  CTC304    60
# 41   CTC305 - 2ºAndar  CTC305    60
# 42   CTC306 - 2ºAndar  CTC306    30
# 43                NaN  ECV303    55
# 44                NaN  ECV310    52
# 45                NaN  ECV311    29
# 46                NaN  ECV312    29
# 47                NaN  ECV313    53
# 48       EEL - Térreo  EEL003    40
# 49       EEL - Térreo  EEL004   100
# 50       EEL - Térreo  EEL008    40
# 51       EEL - Térreo  EEL009    40
# 52       EEL - Térreo  EEL010    40
# 54  ENS211 - 2º andar  ENS211    40
# 55  ENS212 - 2º andar  ENS212    15
# 56  ENS213 - 2º andar  ENS213    50
# 57  ENS215 - 2º andar  ENS215    40
# 58  ENS216 - 2º andar  ENS216    40
# 59  ENS217 - 2º andar  ENS217    26
# 60                NaN  EPS001    50
# 61                NaN  EPS002    30
# 62                NaN  EPS003    50
# 63                NaN  EQA015    25
# 64                NaN  EQA016    25
# 65                NaN  EQA018    45
# 66                NaN  EQA020    35
# 67                NaN  EQA021    35
# 68                NaN  EQA022    35
# 69                NaN  EQA023    45
#
#                                       Características  Ar condicionado  \
# 9   1 Mesa do professor (sala de aula), 1 Quadro p...                1
# 14  1 Projetor multimídia, 40 Carteira com cadeira...                2
# 15  80 Carteira com cadeira separada, 2 Ar condici...                2
# 16  40 Carteira com cadeira separada, 2 Ar condici...                2
# 17  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 18  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 19  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 20  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 21  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 22  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 23  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 24  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 25  1 Ar condicionado, 35 Carteira com cadeira sep...                1
# 26  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 27  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 28  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 29  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 30  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 31  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 32  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 33  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 34  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 35  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 36  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 37  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 38  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 39  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 40  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 41  2 Ar condicionado, 60 Carteira com cadeira sep...                2
# 42  1 Ar condicionado, 30 Carteira com cadeira sep...                1
# 43  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 44  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 45  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 46  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 47  1 Mesa do professor (sala de aula), 1 Projetor...                0
# 48  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 49  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 50  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 51  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 52  1 Mesa do professor (sala de aula), 1 Quadro p...                2
# 54  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 55  1 Ar condicionado, 15 Carteira com cadeira sep...                1
# 56  2 Ar condicionado, 50 Carteira com cadeira sep...                2
# 57  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 58  2 Ar condicionado, 40 Carteira com cadeira sep...                2
# 59  1 Ar condicionado, 26 Carteira com cadeira sep...                1
# 60  50 Carteira com cadeira separada, 2 Ar condici...                2
# 61  30 Carteira com cadeira separada, 1 Ar condici...                1
# 62  50 Carteira com cadeira separada, 1 Ar condici...                1
# 63  25 Carteira com cadeira separada, 1 Projetor m...                1
# 64  1 Ar condicionado, 1 Mesa do professor (sala d...                1
# 65  50 Carteira com cadeira separada, 1 Projetor m...                2
# 66  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 67  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 68  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 69  2 Ar condicionado, 1 Mesa do professor (sala d...                2
#
#     Projetor
# 9          1
# 14         1
# 15         1
# 16         1
# 17         1
# 18         1
# 19         1
# 20         1
# 21         1
# 22         1
# 23         1
# 24         1
# 25         1
# 26         1
# 27         1
# 28         1
# 29         1
# 30         1
# 31         1
# 32         1
# 33         1
# 34         1
# 35         1
# 36         1
# 37         1
# 38         1
# 39         1
# 40         1
# 41         1
# 42         1
# 43         1
# 44         1
# 45         1
# 46         1
# 47         1
# 48         1
# 49         1
# 50         1
# 51         1
# 52         1
# 54         1
# 55         1
# 56         1
# 57         1
# 58         1
# 59         1
# 60         1
# 61         1
# 62         1
# 63         1
# 64         1
# 65         1
# 66         1
# 67         1
# 68         1
# 69         1

# %%
# %%time

# basic sets
C = df_lectures['course'].unique()
T = df_lectures['time_period'].unique()
R = df_rooms['room'].unique()
L = df_lectures['lecture'].unique()


# we define the patterns through the `long_lecture`, which groups lectures
# that span through multiple time periods
long_L = df_lectures.groupby('course')['long_lecture'].unique()
longlecture2lectures = df_lectures.groupby('long_lecture')['lecture'].unique()

P = list()
for c in tqdm(C):
    P_c = list(powerset(long_L[c]))[1:]  # remove empty set
    P_c = [[longlecture2lectures[ll] for ll in p] for p in P_c]
    P_c = [np.concatenate(p) for p in P_c]
    P += P_c
P_idx = np.arange(0,len(P))  # so we can hash it
# Out:
#   0%|          | 0/282 [00:00<?, ?it/s]
# CPU times: user 142 ms, sys: 931 µs, total: 142 ms
# Wall time: 276 ms

# %%
# L_c[c] are the lectures of course c
L_c = df_lectures.groupby('course')['lecture'].unique()

# T_l[l] is the time period in which a lecture happens
T_l = {l: df_lectures.iloc[l]['time_period'] for l in L}

# %%
# then, P[c] will have all the patterns that preserve contiguous room stability
patterns_course = [df_lectures.loc[p[0]]['course'] for p in P]
P_c = dict()
for c in tqdm(C):
    P_c[c] = [i for i, c_p in enumerate(patterns_course) if c_p == c]
# Out:
#   0%|          | 0/282 [00:00<?, ?it/s]

# %%
# then, P[c] will have all the patterns that preserve contiguous room stability
P_c = dict()
for c in tqdm(C):
    P_c[c] = [i for i, c_p in enumerate(patterns_course) if c_p == 0]

P_l = dict()
for l in tqdm(L):
    P_l[l] = list()
    for p_i in P_idx:
        if l in P[p_i]:
            P_l[l].append(p_i)
# Out:
#   0%|          | 0/282 [00:00<?, ?it/s]
#   0%|          | 0/1012 [00:00<?, ?it/s]

# %%
# seats required by pattern
size = {p_i: df_lectures.loc[P[p_i]]['size'].max() for p_i in tqdm(P_idx)}

# R[p] are the rooms suitable for pattern p
R_p = {p_i: df_rooms[df_rooms['size'] >= size[p_i]]['room'].unique() for p_i in tqdm(P_idx)}

R_c = {c: list({r for p_i in P_c[c] for r in R_p[p_i]}) for c in C}
# Out:
#   0%|          | 0/772 [00:00<?, ?it/s]
#   0%|          | 0/772 [00:00<?, ?it/s]

# %%
T_p = {p_i: T_l[l] for p_i in tqdm(P_idx) for l in P[p_i]}

P_rt = dict()
for r in tqdm(R):
    P_rt[r] = dict()
    for t in T:
        P_rt[r][t] = [p_i for p_i in P_idx if r in R_p[p_i] and t in T_p[p_i]]
# Out:
#   0%|          | 0/772 [00:00<?, ?it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]

# %%
w = [len(P[p_i]) for p_i in P_idx]

# %%
data = {
    'C': C,
    'T': T,
    'R': R,
    'L': L,
    'P': P,
    'L_c': L_c,
    'T_l': T_l,
    'P_c': P_c,
    'P_l': P_l,
    'P_rt': P_rt,
    'R_p': R_p,
    'R_c': R_c,
    'w': w,
}

with open('data_small.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
len(P)
# Out:
# 772

# %%
with open('data_small.pkl', 'rb') as f:
    data = pickle.load(f)

C = data['C']
T = data['T']
R = data['R']
L = data['L']
P = data['P']
L_c = data['L_c']
T_l = data['T_l']
P_c = data['P_c']
P_l = data['P_l']
P_rt = data['P_rt']
R_p = data['R_p']
R_c = data['R_c']
w = data['w']

P_idx = np.arange(0, len(P))

# %% [markdown]
# # AMPL

# %%
from amplpy import AMPL

ampl = AMPL()

ampl.read('classroom.mod')
# ampl.readData('classroom-example.dat')

# %%
ampl.getSet('C').setValues(C.astype(str))
ampl.getSet('T').setValues(T.astype(str))
ampl.getSet('R').setValues(R.astype(str))
ampl.getSet('L').setValues(L.astype(str))
ampl.getSet('P').setValues(P_idx.astype(str))

# %%
# %%time

def set_indexed(ampl, name, var, idx):
    SS = ampl.getSet(name)
    for i in tqdm(idx):
        try:
            SS[str(i)].setValues(np.array(var[i]).astype(str))
        except RuntimeError as e:
            print(i)
            raise e

set_indexed(ampl, 'L_c', L_c, C)
# Out:
#   0%|          | 0/282 [00:00<?, ?it/s]
# CPU times: user 60.6 ms, sys: 20.2 ms, total: 80.8 ms
# Wall time: 92.8 ms

# %%
set_indexed(ampl, 'R_p', R_p, P_idx)
set_indexed(ampl, 'P_l', P_l, L)
# Out:
#   0%|          | 0/772 [00:00<?, ?it/s]
#   0%|          | 0/1012 [00:00<?, ?it/s]

# %%
_P_rt = ampl.getSet('P_rt')
for r in tqdm(R):
    for t in T:
        _P_rt[str(r),str(t)].setValues(np.array(P_rt[r][t]).astype(str))
# Out:
#   0%|          | 0/56 [00:00<?, ?it/s]

# %%
ampl.param['w'] = [len(p) for p in P]

# %%
ampl.exportData('ufsc-instance-small.dat')
