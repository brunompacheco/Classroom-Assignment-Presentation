# %%
import pickle

import numpy as np
import pandas as pd

from itertools import product, chain, combinations

from tqdm.notebook import tqdm

def powerset(iterable):
    "powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)"
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
df_classes = pd.read_csv('PI_classes.csv', index_col=0)

df_classes
# Out:
#                                                   Bloco  Capacidade  \
# 0     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 1     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 2     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 3     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 4     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# ...                                                 ...         ...
# 1271   LIN Laboratório de Instrumentação Laboratório 16          16
# 1272   LIN Laboratório de Instrumentação Laboratório 16          16
# 1273         LPR Laboratório de Projetos Laboratório 16          16
# 1274         LPR Laboratório de Projetos Laboratório 16          16
# 1275         LPR Laboratório de Projetos Laboratório 16          16
#
#                 Andar    Sala  \
# 0     ARQ05 - 1ºAndar  ARQ201
# 1     ARQ05 - 1ºAndar  ARQ201
# 2     ARQ05 - 1ºAndar  ARQ201
# 3     ARQ05 - 1ºAndar  ARQ201
# 4     ARQ05 - 1ºAndar  ARQ201
# ...               ...     ...
# 1271              NaN     LIN
# 1272              NaN     LIN
# 1273              NaN     LPR
# 1274              NaN     LPR
# 1275              NaN     LPR
#
#                                               Materia   Codigo   Turma  \
# 0        Historia da Arte, Arquitetura e Urbanismo II  ARQ5622  02207A
# 1       História da Arte, Arquitetura e Urbanismo III  ARQ5623  04207A
# 2                        Arquitetura Latino Americana  ARQ5626  08207A
# 3                             Criatividade e Inovação  EGC5027   09207
# 4                                Análise Estrutural I  EMC5313   10203
# ...                                               ...      ...     ...
# 1271                               Projeto Integrador  DAS5104  07220A
# 1272                       Instrumentação em Controle  DAS5151  06220B
# 1273  Introdução à Engenharia de Controle e Automação  DAS5411  01220C
# 1274  Introdução à Engenharia de Controle e Automação  DAS5411  01220A
# 1275  Introdução à Engenharia de Controle e Automação  DAS5411  01220B
#
#         Horario  Oferecidas  Ocupadas
# 0     2. 0910-3          25        20
# 1     2. 1420-4          25        20
# 2     3. 0910-2          25        11
# 3     3. 1420-4          30        11
# 4     4. 0730-3          20        10
# ...         ...         ...       ...
# 1271  5. 1620-2          21         8
# 1272  6. 1010-2          15        10
# 1273  5. 1010-2          14        10
# 1274  5. 1330-2          14        12
# 1275  5. 1510-2          14        11
#
# [1276 rows x 10 columns]

# %%
df_rooms = pd.read_csv('PI_rooms.csv')
df_rooms
# Out:
#                 Lugar    Sala  Carteiras  \
# 0     ARQ05 - 1ºAndar  ARQ201         45
# 1     ARQ04 - 1ºAndar  ARQ202         40
# 2     ARQ03 - 1ºAndar  ARQ203         40
# 3      ARQ02 - Térreo  ARQ204         40
# 4    ARQ09 - 2º Andar  ARQ301         20
# ..                ...     ...        ...
# 123               NaN  PGEAS2         25
# 124               NaN  SPL313         30
# 125               NaN  SPL314         15
# 126               NaN  SPL315         30
# 127               NaN  SPL316         15
#
#                                        Características  Ar condicionado  \
# 0    2 Ar condicionado, 1 Mesa do professor (sala d...                2
# 1    1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# 2    2 Ar condicionado, 1 Projetor multimídia, 1 Me...                2
# 3    2 Ar condicionado, 1 Projetor multimídia, 1 Qu...                2
# 4    1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# ..                                                 ...              ...
# 123                                        Laboratório                0
# 124                                        Laboratório                0
# 125                                        Laboratório                0
# 126                                        Laboratório                0
# 127                                        Laboratório                0
#
#      Projetor  Laboratório
# 0           1            0
# 1           1            0
# 2           1            0
# 3           1            0
# 4           1            0
# ..        ...          ...
# 123         0            1
# 124         0            1
# 125         0            1
# 126         0            1
# 127         0            1
#
# [128 rows x 7 columns]

# %% [markdown]
# # Lecture required seats fix

# %%
# we assume that the actual amount of seats required is at most the amount offered by the class allocated
df_classes['Ocupadas_fix'] = df_classes[['Capacidade', 'Ocupadas']].min(axis='columns')

# %% [markdown]
# # Lab rooms+lectures

# %%
labs = df_rooms[df_rooms['Laboratório'] > 0]['Sala']

# remove labs
df_rooms = df_rooms[df_rooms['Laboratório'] == 0].drop(columns=['Laboratório'])

print(f"Labs: {len(labs)}")

df_rooms
# Out:
# Labs: 60
#                Lugar    Sala  Carteiras  \
# 0    ARQ05 - 1ºAndar  ARQ201         45
# 1    ARQ04 - 1ºAndar  ARQ202         40
# 2    ARQ03 - 1ºAndar  ARQ203         40
# 3     ARQ02 - Térreo  ARQ204         40
# 4   ARQ09 - 2º Andar  ARQ301         20
# ..               ...     ...        ...
# 65               NaN  EQA018         45
# 66               NaN  EQA020         35
# 67               NaN  EQA021         35
# 68               NaN  EQA022         35
# 69               NaN  EQA023         45
#
#                                       Características  Ar condicionado  \
# 0   2 Ar condicionado, 1 Mesa do professor (sala d...                2
# 1   1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# 2   2 Ar condicionado, 1 Projetor multimídia, 1 Me...                2
# 3   2 Ar condicionado, 1 Projetor multimídia, 1 Qu...                2
# 4   1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# ..                                                ...              ...
# 65  50 Carteira com cadeira separada, 1 Projetor m...                2
# 66  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 67  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 68  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 69  2 Ar condicionado, 1 Mesa do professor (sala d...                2
#
#     Projetor
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 65         1
# 66         1
# 67         1
# 68         1
# 69         1
#
# [68 rows x 6 columns]

# %%
# remove lectures that occur in labs
df_classes = df_classes[~df_classes['Sala'].isin(labs)]
df_classes = df_classes[df_classes['Sala'] != 'LABCIG']
df_classes
# Out:
#                                                   Bloco  Capacidade  \
# 0     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 1     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 2     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 3     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# 4     CTC 39 - Bloco A (etapa 1) - Sala de aula Sala...          45
# ...                                                 ...         ...
# 1095           EQA023 Sala de aula Sala com carteira 45          45
# 1096           EQA023 Sala de aula Sala com carteira 45          45
# 1097           EQA023 Sala de aula Sala com carteira 45          45
# 1098           EQA023 Sala de aula Sala com carteira 45          45
# 1099           EQA023 Sala de aula Sala com carteira 45          45
#
#                 Andar    Sala  \
# 0     ARQ05 - 1ºAndar  ARQ201
# 1     ARQ05 - 1ºAndar  ARQ201
# 2     ARQ05 - 1ºAndar  ARQ201
# 3     ARQ05 - 1ºAndar  ARQ201
# 4     ARQ05 - 1ºAndar  ARQ201
# ...               ...     ...
# 1095              NaN  EQA023
# 1096              NaN  EQA023
# 1097              NaN  EQA023
# 1098              NaN  EQA023
# 1099              NaN  EQA023
#
#                                                 Materia   Codigo   Turma  \
# 0          Historia da Arte, Arquitetura e Urbanismo II  ARQ5622  02207A
# 1         História da Arte, Arquitetura e Urbanismo III  ARQ5623  04207A
# 2                          Arquitetura Latino Americana  ARQ5626  08207A
# 3                               Criatividade e Inovação  EGC5027   09207
# 4                                  Análise Estrutural I  EMC5313   10203
# ...                                                 ...      ...     ...
# 1095  Operações Unitárias de Transferência de Calor ...  EQA5333   08216
# 1096                      Fenômenos de Transferência II  EQA5416   06216
# 1097                 Programação Econômica e Financeira  EPS5211   07216
# 1098  Operações Unitárias de Transferência de Quanti...  EQA5313   06215
# 1099  Operações Unitárias de Transferência de Quanti...  EQA5313   06216
#
#         Horario  Oferecidas  Ocupadas  Ocupadas_fix
# 0     2. 0910-3          25        20            20
# 1     2. 1420-4          25        20            20
# 2     3. 0910-2          25        11            11
# 3     3. 1420-4          30        11            11
# 4     4. 0730-3          20        10            10
# ...         ...         ...       ...           ...
# 1095  5. 1330-2          20        20            20
# 1096  5. 1510-2          20        20            20
# 1097  6. 0730-3          31        26            26
# 1098  6. 1330-2          20        15            15
# 1099  6. 1330-2          20        13            13
#
# [1100 rows x 11 columns]

# %% [markdown]
# # Room names

# %%
df_classes['Sala'].str.replace(' ','').nunique()
# Out:
# 65

# %%
df_rooms['Sala'].str.replace(' ','').nunique()
# Out:
# 68

# %%
df_classes['Sala'] = df_classes['Sala'].str.replace(' ', '')
df_rooms['Sala'] = df_rooms['Sala'].str.replace(' ', '')

# %%
# rooms in `df_classes` that are not in `df_rooms`
set(df_classes['Sala'].unique()).difference(set(df_rooms['Sala'].unique()))
# Out:
# set()

# %% [markdown]
# # Course-class matching

# %%
# are there multiple classes attending the same lecture at the same time in the same room?
seats_req = df_classes.groupby(['Codigo', 'Horario', 'Sala'])['Ocupadas'].sum()
seats_req
# Out:
# Codigo   Horario    Sala
# ARQ5115  2. 0910-3  ARQ303    27
#          2. 1830-4  ARQ202    27
#          7. 0730-1  ARQ311    27
# ARQ5515  4. 1510-3  ARQ305    24
#                     CTC207    18
#                               ..
# QMC5229  4. 1010-2  CTC304    37
#          6. 0730-2  CTC305    37
# QMC5350  2. 1510-2  EEL010    25
#          6. 1010-2  EQA020    16
# QMC5351  6. 1330-2  EQA020    21
# Name: Ocupadas, Length: 878, dtype: int64

# %%
seats_avail = df_classes.groupby(['Codigo', 'Horario', 'Sala'])['Capacidade'].first()
seats_avail
# Out:
# Codigo   Horario    Sala
# ARQ5115  2. 0910-3  ARQ303    20
#          2. 1830-4  ARQ202    40
#          7. 0730-1  ARQ311    20
# ARQ5515  4. 1510-3  ARQ305    40
#                     CTC207    60
#                               ..
# QMC5229  4. 1010-2  CTC304    60
#          6. 0730-2  CTC305    60
# QMC5350  2. 1510-2  EEL010    40
#          6. 1010-2  EQA020    35
# QMC5351  6. 1330-2  EQA020    35
# Name: Capacidade, Length: 878, dtype: int64

# %%
seats_req[seats_req > seats_avail] - seats_avail[seats_req > seats_avail]
# Out:
# Codigo   Horario    Sala
# ARQ5115  2. 0910-3  ARQ303     7
#          7. 0730-1  ARQ311     7
# ARQ5642  3. 0910-3  ARQ310    15
# ARQ5658  5. 1010-2  CTC306    13
# ARQ5662  5. 1010-2  ARQ309    14
# ECV2101  4. 1830-3  CTC201     4
# ECV5104  4. 1010-2  EQA020     2
# ECV5213  5. 1010-2  ECV312     1
#          6. 1010-2  ECV312     1
# ECV5631  5. 0820-4  EQA016     7
# ECV5643  5. 1330-2  ARQ202     2
# ECV5645  5. 1510-2  ARQ204     7
# ECV5648  2. 0730-3  ARQ204     5
# EEL7030  3. 0820-2  CTC206    16
# EGC5036  6. 1830-2  CTC102     8
# EGR5611  3. 0910-3  ARQ303     1
#          6. 0910-3  ARQ303     1
# EGR5612  2. 1420-3  ARQ303     2
#          4. 1420-3  ARQ303     2
# EMC5138  6. 0820-2  CTC206     5
# EMC5417  2. 1010-2  EEL010     3
#          5. 0820-2  ENS211     3
# EMC5443  2. 0910-3  EQA015     2
# EPS7032  6. 1830-1  CTC111     2
# FSC5002  3. 0730-2  EEL009     5
#          4. 1330-2  EEL008     5
#          4. 1620-2  CTC303     3
#          5. 1620-2  ENS213     3
#          6. 1330-2  EEL008     5
# FSC5103  5. 1620-2  CTC106     3
# FSC5113  2. 1330-2  CTC205     5
#          4. 0820-2  CTC105     5
# INE5108  5. 0730-3  EQA015     3
# INE5202  2. 1330-2  CTC206     3
#          4. 1010-2  CTC113     5
#          4. 1620-2  CTC209     6
#          5. 0820-2  CTC206     5
#                     CTC207     6
# INE5605  2. 1830-4  CTC208     6
#          6. 2020-2  CTC208     6
# INE5638  7. 0730-1  CTC103     5
# QMC5222  6. 1330-2  CTC204     3
# dtype: int64

# %%
df_classes[df_classes['Codigo'] == 'EEL7030']
# Out:
#                                                  Bloco  Capacidade    Andar  \
# 232  CTC02 - Bloco B - Sala de Aula CTC 108 - Sala ...          40   Térreo
# 233  CTC02 - Bloco B - Sala de Aula CTC 108 - Sala ...          40   Térreo
# 467  CTC02 - Bloco B - Sala de Aula CTC 206 - Sala ...          40  1ºAndar
# 468  CTC02 - Bloco B - Sala de Aula CTC 206 - Sala ...          40  1ºAndar
# 469  CTC02 - Bloco B - Sala de Aula CTC 206 - Sala ...          40  1ºAndar
# 470  CTC02 - Bloco B - Sala de Aula CTC 206 - Sala ...          40  1ºAndar
#
#        Sala             Materia   Codigo   Turma    Horario  Oferecidas  \
# 232  CTC108  Microprocessadores  EEL7030  04235A  2. 1510-2          18
# 233  CTC108  Microprocessadores  EEL7030  04235B  2. 1510-2          18
# 467  CTC206  Microprocessadores  EEL7030  04202A  3. 0820-2          19
# 468  CTC206  Microprocessadores  EEL7030  04202B  3. 0820-2          11
# 469  CTC206  Microprocessadores  EEL7030  04202C  3. 0820-2          20
# 470  CTC206  Microprocessadores  EEL7030   10213  3. 0820-2           8
#
#      Ocupadas  Ocupadas_fix
# 232        18            18
# 233        16            16
# 467        19            19
# 468        11            11
# 469        20            20
# 470         6             6

# %% [markdown]
# So there are many cases in which the rooms are overbooked. We will ignore this for now and let the solver handle it.

# %%
# every course-room-time combination is considered a lecture (actualy a long lecture)
df_lectures = df_classes.groupby(['Codigo', 'Horario', 'Sala'])['Ocupadas'].sum().reset_index()
df_lectures['long_lecture'] = df_lectures.index

# each row is a lecture
df_lectures
# Out:
#       Codigo    Horario    Sala  Ocupadas  long_lecture
# 0    ARQ5115  2. 0910-3  ARQ303        27             0
# 1    ARQ5115  2. 1830-4  ARQ202        27             1
# 2    ARQ5115  7. 0730-1  ARQ311        27             2
# 3    ARQ5515  4. 1510-3  ARQ305        24             3
# 4    ARQ5515  4. 1510-3  CTC207        18             4
# ..       ...        ...     ...       ...           ...
# 873  QMC5229  4. 1010-2  CTC304        37           873
# 874  QMC5229  6. 0730-2  CTC305        37           874
# 875  QMC5350  2. 1510-2  EEL010        25           875
# 876  QMC5350  6. 1010-2  EQA020        16           876
# 877  QMC5351  6. 1330-2  EQA020        21           877
#
# [878 rows x 5 columns]

# %%
df_lectures['n_lectures'] = df_lectures['Horario'].str.split('-').apply(lambda x: x[-1])
df_lectures
# Out:
#       Codigo    Horario    Sala  Ocupadas  long_lecture n_lectures
# 0    ARQ5115  2. 0910-3  ARQ303        27             0          3
# 1    ARQ5115  2. 1830-4  ARQ202        27             1          4
# 2    ARQ5115  7. 0730-1  ARQ311        27             2          1
# 3    ARQ5515  4. 1510-3  ARQ305        24             3          3
# 4    ARQ5515  4. 1510-3  CTC207        18             4          3
# ..       ...        ...     ...       ...           ...        ...
# 873  QMC5229  4. 1010-2  CTC304        37           873          2
# 874  QMC5229  6. 0730-2  CTC305        37           874          2
# 875  QMC5350  2. 1510-2  EEL010        25           875          2
# 876  QMC5350  6. 1010-2  EQA020        16           876          2
# 877  QMC5351  6. 1330-2  EQA020        21           877          2
#
# [878 rows x 6 columns]

# %%
df_lectures = df_lectures.loc[df_lectures.index.repeat(df_lectures['n_lectures'])]
df_lectures = df_lectures.reset_index().drop(columns=['index', 'n_lectures'])
df_lectures['lecture'] = df_lectures.index

df_lectures
# Out:
#        Codigo    Horario    Sala  Ocupadas  long_lecture  lecture
# 0     ARQ5115  2. 0910-3  ARQ303        27             0        0
# 1     ARQ5115  2. 0910-3  ARQ303        27             0        1
# 2     ARQ5115  2. 0910-3  ARQ303        27             0        2
# 3     ARQ5115  2. 1830-4  ARQ202        27             1        3
# 4     ARQ5115  2. 1830-4  ARQ202        27             1        4
# ...       ...        ...     ...       ...           ...      ...
# 1980  QMC5350  2. 1510-2  EEL010        25           875     1980
# 1981  QMC5350  6. 1010-2  EQA020        16           876     1981
# 1982  QMC5350  6. 1010-2  EQA020        16           876     1982
# 1983  QMC5351  6. 1330-2  EQA020        21           877     1983
# 1984  QMC5351  6. 1330-2  EQA020        21           877     1984
#
# [1985 rows x 6 columns]

# %% [markdown]
# # Time periods

# %%
set([t.split(' ')[-1] for t in np.sort(df_lectures['Horario'].unique())])
# Out:
# {'0730-1',
#  '0730-2',
#  '0730-3',
#  '0820-1',
#  '0820-2',
#  '0820-3',
#  '0820-4',
#  '0910-1',
#  '0910-2',
#  '0910-3',
#  '1010-1',
#  '1010-2',
#  '1100-1',
#  '1330-1',
#  '1330-2',
#  '1330-3',
#  '1330-4',
#  '1420-2',
#  '1420-3',
#  '1420-4',
#  '1510-2',
#  '1510-3',
#  '1620-1',
#  '1620-2',
#  '1710-1',
#  '1830-1',
#  '1830-2',
#  '1830-3',
#  '1830-4',
#  '2020-2'}

# %%
days = np.arange(1,7+1)
times = ['0730', '0820', '0910', '1010', '1100', '1330', '1420', '1510', '1620', '1710', '1830', '1920', '2020', '2110']

time_periods = product(days, times)
time_periods = [str(d)+'-'+t for d, t in time_periods]
time_periods
# Out:
# ['1-0730',
#  '1-0820',
#  '1-0910',
#  '1-1010',
#  '1-1100',
#  '1-1330',
#  '1-1420',
#  '1-1510',
#  '1-1620',
#  '1-1710',
#  '1-1830',
#  '1-1920',
#  '1-2020',
#  '1-2110',
#  '2-0730',
#  '2-0820',
#  '2-0910',
#  '2-1010',
#  '2-1100',
#  '2-1330',
#  '2-1420',
#  '2-1510',
#  '2-1620',
#  '2-1710',
#  '2-1830',
#  '2-1920',
#  '2-2020',
#  '2-2110',
#  '3-0730',
#  '3-0820',
#  '3-0910',
#  '3-1010',
#  '3-1100',
#  '3-1330',
#  '3-1420',
#  '3-1510',
#  '3-1620',
#  '3-1710',
#  '3-1830',
#  '3-1920',
#  '3-2020',
#  '3-2110',
#  '4-0730',
#  '4-0820',
#  '4-0910',
#  '4-1010',
#  '4-1100',
#  '4-1330',
#  '4-1420',
#  '4-1510',
#  '4-1620',
#  '4-1710',
#  '4-1830',
#  '4-1920',
#  '4-2020',
#  '4-2110',
#  '5-0730',
#  '5-0820',
#  '5-0910',
#  '5-1010',
#  '5-1100',
#  '5-1330',
#  '5-1420',
#  '5-1510',
#  '5-1620',
#  '5-1710',
#  '5-1830',
#  '5-1920',
#  '5-2020',
#  '5-2110',
#  '6-0730',
#  '6-0820',
#  '6-0910',
#  '6-1010',
#  '6-1100',
#  '6-1330',
#  '6-1420',
#  '6-1510',
#  '6-1620',
#  '6-1710',
#  '6-1830',
#  '6-1920',
#  '6-2020',
#  '6-2110',
#  '7-0730',
#  '7-0820',
#  '7-0910',
#  '7-1010',
#  '7-1100',
#  '7-1330',
#  '7-1420',
#  '7-1510',
#  '7-1620',
#  '7-1710',
#  '7-1830',
#  '7-1920',
#  '7-2020',
#  '7-2110']

# %%
df_lectures['Horario'] = df_lectures['Horario'].str.split('-').apply(lambda x: x[0])
df_lectures['Horario'] = df_lectures['Horario'].str.replace('. ', '-')

df_lectures
# Out:
# <ipython-input-20-01be645fcdbb>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lectures['Horario'] = df_lectures['Horario'].str.replace('. ', '-')
#        Codigo Horario    Sala  Ocupadas  long_lecture  lecture
# 0     ARQ5115  2-0910  ARQ303        27             0        0
# 1     ARQ5115  2-0910  ARQ303        27             0        1
# 2     ARQ5115  2-0910  ARQ303        27             0        2
# 3     ARQ5115  2-1830  ARQ202        27             1        3
# 4     ARQ5115  2-1830  ARQ202        27             1        4
# ...       ...     ...     ...       ...           ...      ...
# 1980  QMC5350  2-1510  EEL010        25           875     1980
# 1981  QMC5350  6-1010  EQA020        16           876     1981
# 1982  QMC5350  6-1010  EQA020        16           876     1982
# 1983  QMC5351  6-1330  EQA020        21           877     1983
# 1984  QMC5351  6-1330  EQA020        21           877     1984
#
# [1985 rows x 6 columns]

# %% [markdown]
# # Formulation

# %%
df_lectures = df_lectures.rename({
    'Codigo': 'course',
    'Horario': 'time_period',
    'Sala': 'room',
    'Ocupadas': 'size',
}, axis='columns')

df_lectures
# Out:
#        course time_period    room  size  long_lecture  lecture
# 0     ARQ5115      2-0910  ARQ303    27             0        0
# 1     ARQ5115      2-0910  ARQ303    27             0        1
# 2     ARQ5115      2-0910  ARQ303    27             0        2
# 3     ARQ5115      2-1830  ARQ202    27             1        3
# 4     ARQ5115      2-1830  ARQ202    27             1        4
# ...       ...         ...     ...   ...           ...      ...
# 1980  QMC5350      2-1510  EEL010    25           875     1980
# 1981  QMC5350      6-1010  EQA020    16           876     1981
# 1982  QMC5350      6-1010  EQA020    16           876     1982
# 1983  QMC5351      6-1330  EQA020    21           877     1983
# 1984  QMC5351      6-1330  EQA020    21           877     1984
#
# [1985 rows x 6 columns]

# %%
df_rooms = df_rooms.rename({
    'Sala': 'room',
    'Carteiras': 'size'
}, axis='columns')

df_rooms
# Out:
#                Lugar    room  size  \
# 0    ARQ05 - 1ºAndar  ARQ201    45
# 1    ARQ04 - 1ºAndar  ARQ202    40
# 2    ARQ03 - 1ºAndar  ARQ203    40
# 3     ARQ02 - Térreo  ARQ204    40
# 4   ARQ09 - 2º Andar  ARQ301    20
# ..               ...     ...   ...
# 65               NaN  EQA018    45
# 66               NaN  EQA020    35
# 67               NaN  EQA021    35
# 68               NaN  EQA022    35
# 69               NaN  EQA023    45
#
#                                       Características  Ar condicionado  \
# 0   2 Ar condicionado, 1 Mesa do professor (sala d...                2
# 1   1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# 2   2 Ar condicionado, 1 Projetor multimídia, 1 Me...                2
# 3   2 Ar condicionado, 1 Projetor multimídia, 1 Qu...                2
# 4   1 Ar condicionado, 1 Projetor multimídia, 1 Me...                1
# ..                                                ...              ...
# 65  50 Carteira com cadeira separada, 1 Projetor m...                2
# 66  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 67  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 68  2 Ar condicionado, 35 Carteira com cadeira sep...                2
# 69  2 Ar condicionado, 1 Mesa do professor (sala d...                2
#
#     Projetor
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ..       ...
# 65         1
# 66         1
# 67         1
# 68         1
# 69         1
#
# [68 rows x 6 columns]

# %%
# %%time

# basic sets
C = df_lectures['course'].unique()
T = df_lectures['time_period'].unique()
R = df_rooms['room'].unique()
L = df_lectures['lecture'].unique()


# we define the patterns through the `long_lecture`, which groups lectures
# that span through multiple time periods
long_L = df_lectures.groupby('course')['long_lecture'].unique()
longlecture2lectures = df_lectures.groupby('long_lecture')['lecture'].unique()

P = list()
for c in tqdm(C):
    P_c = list(powerset(long_L[c]))[1:]  # remove empty set
    P_c = [[longlecture2lectures[ll] for ll in p] for p in P_c]
    P_c = [np.concatenate(p) for p in P_c]
    P += P_c
P_idx = np.arange(0,len(P))  # so we can hash it
# Out:
#   0%|          | 0/412 [00:00<?, ?it/s]
# CPU times: user 2.17 s, sys: 12 ms, total: 2.19 s
# Wall time: 2.18 s

# %%
# L_c[c] are the lectures of course c
L_c = df_lectures.groupby('course')['lecture'].unique()

# T_l[l] is the time period in which a lecture happens
T_l = {l: df_lectures.iloc[l]['time_period'] for l in L}

# %%
# then, P[c] will have all the patterns that preserve contiguous room stability
patterns_course = [df_lectures.loc[p[0]]['course'] for p in P]
P_c = dict()
for c in tqdm(C):
    P_c[c] = [i for i, c_p in enumerate(patterns_course) if c_p == c]
# Out:
#   0%|          | 0/412 [00:00<?, ?it/s]

# %%
# then, P[c] will have all the patterns that preserve contiguous room stability
patterns_course = [df_lectures.loc[p[0]]['course'] for p in P]
P_c = dict()
for c in tqdm(C):
    P_c[c] = [i for i, c_p in enumerate(patterns_course) if c_p == 0]

P_l = dict()
for l in tqdm(L):
    P_l[l] = list()
    for p_i in P_idx:
        if l in P[p_i]:
            P_l[l].append(p_i)

# %%
# seats required by pattern
size = {p_i: df_lectures.loc[P[p_i]]['size'].max() for p_i in tqdm(P_idx)}

# R[p] are the rooms suitable for pattern p
R_p = {p_i: df_rooms[df_rooms['size'] >= size[p_i]]['room'].unique() for p_i in tqdm(P_idx)}

R_c = {c: list({r for p_i in P_c[c] for r in R_p[p_i]}) for c in C}

# %%
T_p = {p_i: T_l[l] for p_i in tqdm(P_idx) for l in P[p_i]}

P_rt = dict()
for r in tqdm(R):
    P_rt[r] = dict()
    for t in T:
        P_rt[r][t] = [p_i for p_i in P_idx if r in R_p[p_i] and t in T_p[p_i]]
# Out:
#   0%|          | 0/77148 [00:00<?, ?it/s]
#   0%|          | 0/68 [00:00<?, ?it/s]

# %%
w = [len(P[p_i]) for p_i in P_idx]

# %%
data = {
    'C': C,
    'T': T,
    'R': R,
    'L': L,
    'P': P,
    'L_c': L_c,
    'T_l': T_l,
    'P_c': P_c,
    'P_l': P_l,
    'P_rt': P_rt,
    'R_p': R_p,
    'R_c': R_c,
    'w': w,
}

with open('data.pkl', 'wb') as f:
    pickle.dump(data, f)

# %%
with open('data.pkl', 'rb') as f:
    data = pickle.load(f)

C = data['C']
T = data['T']
R = data['R']
L = data['L']
P = data['P']
L_c = data['L_c']
T_l = data['T_l']
P_c = data['P_c']
P_l = data['P_l']
P_rt = data['P_rt']
R_p = data['R_p']
R_c = data['R_c']
w = data['w']

P_idx = np.arange(0, len(P))

# %% [markdown]
# # AMPL

# %%
from amplpy import AMPL

ampl = AMPL()

ampl.read('classroom.mod')
# ampl.readData('classroom-example.dat')

# %%
ampl.getSet('C').setValues(C.astype(str))
ampl.getSet('T').setValues(T.astype(str))
ampl.getSet('R').setValues(R.astype(str))
ampl.getSet('L').setValues(L.astype(str))
ampl.getSet('P').setValues(P_idx.astype(str))

# %%
# %%time

def set_indexed(ampl, name, var, idx):
    SS = ampl.getSet(name)
    for i in idx:
        try:
            SS[str(i)].setValues(np.array(var[i]).astype(str))
        except RuntimeError as e:
            print(i)
            raise e

set_indexed(ampl, 'L_c', L_c, C)
set_indexed(ampl, 'R_p', R_p, P_idx)
set_indexed(ampl, 'R_c', R_c, C)
set_indexed(ampl, 'P_c', P_c, C)
set_indexed(ampl, 'P_l', P_l, L)
# Out:
# CPU times: user 10.9 s, sys: 772 ms, total: 11.7 s
# Wall time: 15.2 s

# %%
_P_rt = ampl.getSet('P_rt')
for r in R:
    for t in T:
        _P_rt[str(r),str(t)].setValues(P_rt[r][t])

# %%
ampl.exportData('ufsc-instance.dat')
